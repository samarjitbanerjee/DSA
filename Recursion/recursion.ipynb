# %%
import pandas as pd
import numpy as np
import sys
import os
import argparse

# %% [markdown]
# #### Simple Recursion Function for understanding

# %%
def recursion_example(n):
    """A simple recursive function that prints numbers from n to 0."""
    if n < 0:
        return
    print(n)
    recursion_example(n - 1)

recursion_example(5)

### inside stack memory first main function(recursion_example) is called
### then the function calls itself with n-1 until n is less than 0
### when n is less than 0, the function returns and the stack unwinds
### the output will be 5, 4, 3, 2, 1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
